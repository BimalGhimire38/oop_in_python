# %% [markdown]
# 2082/05/25   04:42 PM
#
# # Gen-Z Protest ...
# ## Learning OOP ( Revising )
#
# [YouTube Video Link](https://youtu.be/Mf2RdpEiXjU)

# %%
# 2082/05/25  08:39 PM, PM ko banne vaera tanab vairaxa yr

class Atm:
    # __init__ method is a special method in python class
    # it is called a constructor and is automatically called when an object of the class is created
    def __init__(self):
        self.pin = ""
        self.balance =0
        self.menu()
        print("Thank you for using ATM")
    
    def menu(self):
        user_input = input('''0
                           Helloe, How would you like to proceed?
                           1. Enter 1 to create PIN
                           2. Enter 2 to deposit 
                           3. Enter 3 to withdraw
                           4. Enter 4 to check balance
                           5. Enter 5 to exit
                           ''')
        if user_input=='1':
            self.create_pin()

        elif user_input=='2':
            # print("Deposit")
            self.deposit()

        elif  user_input=='3':
            self.withdraw()

        elif user_input=='4':
            self.check_balance()

        else:
            print("Exit")

    def create_pin(self):
        self.pin = input("Enter Your PIN")
        print("Pin Set Successfully")
    def deposit(self):
        temp = input("Enter your PIN: ")
        if temp==self.pin:
            amount = int(input("Enter the anmount to deposit : "))
            self.balance+=amount
            print("Deposit Successfully")

    def withdraw(self):
        temp = input("Enter your PIN: ")
        if temp==self.pin:
            amount = int(input("Enter the anmount to withdraw : "))

            if amount<=self.balance:
                self.balance -=amount
                print("Withdrawn Successfully")
            else:
                print("Insufficient Balance")
        else:
            print("Invalid PIN")

    def check_balance(self):
        temp = input("Enter your PIN: ")
        if temp==self.pin:
            print(f"Your balance is {self.balance}")
    


b = Atm()
# Out:
# Exit
# Thank you for using ATM

# %% [markdown]
# 2082/05/26  06:02 PM
# @ Home, Lalitpur
# [Current time video link](https://youtu.be/Mf2RdpEiXjU?t=3367)

# %% [markdown]
# # What is self
# self is also a object
# Self represents the object itself with which we are working

# %%
# print(id(self))

# %% [markdown]
# # Creating a Class to handle Fraction i.e 5/6...

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Sep 11 18:14:29 2025

@author: BIMAL
"""
class Fraction:
    def __init__(self,n,d):
        self.num = n
        self.den = d
        
    def __str__(self):
        return "{}/{}".format(self.num,self.den)

    def __add__(self,other):
        temp_num = self.num*other.den + other.num*self.den
        temp_den = self.den*other.den
        
        return "{}/{}".format(temp_num,temp_den)
    
    def __sub__(self,other):
        temp_num = self.num*other.den - other.num*self.den
        temp_den = self.den*other.den
        
        return "{}/{}".format(temp_num,temp_den)
    
    def __mul__(self,other):
        temp_num = self.num*other.num 
        temp_den = self.den*other.den
        
        return "{}/{}".format(temp_num,temp_den)
        
    def __truediv__(self,other):
        temp_num = self.num*other.den
        temp_den = self.den*other.num
        
        return "{}/{}".format(temp_num,temp_den)

# %% [markdown]
# # Encapsulation

# %% [markdown]
# If you make private variables or methods by adding double underscore (__) before name , another instance of class is created as _ClassName.. and all these variables are accessed through these internally.... SO even if self.__balance is private , we can modify this externally by b._Atm__balance = 2000

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Sep 10 21:03:56 2025

@author: BIMAL
"""

# 2082/05/25  09:04 PM, PM ko banne vaera tanab vairaxa yr

class Atm:
    
    # Magic Methods in Python (__magic_method_name__)
    
    # __init__ method is a special method in python class
    # it is called a constructor and is automatically called when an object of the class is created
    
    # Instance Variable are those variable whose value is different for different object
    def __init__(self):
        self.__pin = ""
        self.__balance =0
        self.menu()
        print("Thank you for using ATM")
        print(id(self))
    
    def menu(self):
        user_input = input('''0
                           Helloe, How would you like to proceed?
                           1. Enter 1 to create PIN
                           2. Enter 2 to deposit 
                           3. Enter 3 to withdraw
                           4. Enter 4 to check balance
                           5. Enter 5 to exit
                           ''')
        if user_input=='1':
            self.create_pin()

        elif user_input=='2':
            # print("Deposit")
            self.deposit()

        elif  user_input=='3':
            self.withdraw()

        elif user_input=='4':
            self.check_balance()

        else:
            print("Exit")

    def create_pin(self):
        self.__pin = input("Enter Your PIN")
        print("Pin Set Successfully")
    def deposit(self):
        temp = input("Enter your PIN: ")
        if temp==self.__pin:
            amount = int(input("Enter the anmount to deposit : "))
            self.__balance+=amount
            print("Deposit Successfully")

    def withdraw(self):
        temp = input("Enter your PIN: ")
        if temp==self.__pin:
            amount = int(input("Enter the anmount to withdraw : "))

            if amount<=self.balance:
                self.__balance -=amount
                print("Withdrawn Successfully")
            else:
                print("Insufficient Balance")
        else:
            print("Invalid PIN")

    def check_balance(self):
        temp = input("Enter your PIN: ")
        if temp==self.__pin:
            print(f"Your balance is {self.__balance}")
    


b = Atm()
# Out:
# Exit
# Thank you for using ATM
# 1707441063312

# %% [markdown]
# Reference Variable
#
#
# if you call the class as Atm() without storing in any variable
#
# but b = Atm()
# here, b in the reference variable

# %% [markdown]
# # Pass by Reference
# 2082/05/27  30:00 PM

# %%
class Customer:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
def greet(customer):
    if customer.gender == "Male":
        print("Hello",customer.name, "Sir")
        
    else:
        print("Hello",customer.name, "Ma'am")
        
        
        
cust = Customer("Bimal", "Male")

greet(cust)
# Out:
# Hello Bimal Sir

# %% [markdown]
# [Video link at current time](https://youtu.be/Mf2RdpEiXjU?t=7106)

# %%
class Customer:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
def greet(customer):
    if customer.gender == "Male":
        print("Hello",customer.name, "Sir")
        
    else:
        print("Hello",customer.name, "Ma'am")
        
    cust2 = Customer("BIMALA","Female")
    return cust2

        
        
cust = Customer("Bimal", "Male")
new_cust = greet(cust)
print(new_cust.name)
# Out:
# Hello Bimal Sir
# BIMALA

# %% [markdown]
# From above example,
# We can pass a class object into a function and we can also return a class object from the function

# %% [markdown]
# # Pass by Reference Example

# %%
class Customer:
    def __init__(self,name):
        self.name = name
        
def greet(customer):
       print(id(customer))
cust = Customer("Bimal")
print(id(cust))

greet(cust)

# These two variable will point to the same memory location
# Out:
# 1707441062304
# 1707441062304

# %% [markdown]
# # Another example of Pass by Reference

# %%
class Customer:
    def __init__(self,name):
        self.name = name
        
def greet(customer):
    customer.name = "Ghimire"
    print(customer.name)
cust = Customer("Bimala")
#print(id(cust))
print(cust.name)
greet(cust)
print(cust.name)
# These two variable will point to the same memory location
# Out:
# Bimala
# Ghimire
# Ghimire

# %%
class Customer:
    def __init__(self,name):
        self.name = name
        
def greet(customer):
    print(id(customer))
    customer.name = "Ghimire"
    print(customer.name)
    print(id(customer))
cust = Customer("Bimala")
#print(id(cust))
print(cust.name)
greet(cust)
print(cust.name)
# These two variable will point to the same memory location
# Out:
# Bimala
# 1707441062304
# Ghimire
# 1707441062304
# Ghimire

# %% [markdown]
# # Objects are mutuable as proved in above code ...
# Two memory address are same before editing and after editing
# same as list , dictionary

# %%
def change(L):
    print(id(L))
    L.append(4)
    print(id(L))

l1 = list([1,2,3])
print(id(l1))
change(l1[:])   # passsing copy of list

print(l1)
# Out:
# 1707441169280
# 1707441220096
# 1707441220096
# [1, 2, 3]

# %% [markdown]
# So in pass by Reference ... Pass the mutuable data types as copy,, and immutable data type directly

# %%
# class Customer:
#     def __init__(self,name):
#         self.name = name
        
# def greet(customer):
#     print(id(customer))
#     customer.name = "Ghimire"
#     print(customer.name)
#     print(id(customer))
# cust = Customer("Bimala")
# #print(id(cust))
# print(cust.name)
# greet(cust)
# print(cust.name)
# # These two variable will point to the same memory location

# %% [markdown]
# Example of immutable data type

# %%
def change(L):
    print(id(L))
    L=L + (4,5)
    print(id(L))

l1 = (1,2,3)
print(id(l1))
change(l1)   # passsing copy of list

print(l1)
# Out:
# 1707441109888
# 1707441109888
# 1707441199984
# (1, 2, 3)

# %% [markdown]
# # Static Variables

# %% [markdown]
# Instance Variable --> different for each object
# Static Variable are needed to store same valus for each objects
#
#
# But we may need some variable which holds similar valus for each object like a Customer number / Student Number / IDs

# %% [markdown]
# Static variables are defined outside of the constructor

# %%
class Atm:
    # static/class variable
    counter = 1
    
    def __init__(self):
        self.__pin = ""
        self.__balance =0
        self.sno = Atm.counter
        Atm.counter += 1

# %% [markdown]
# c1 = Atm()
#
# c2 = Atm()
#
# c3 = Atm()
#
# c1.sno
# Out[51]: 2
#
# c2.sno
# Out[52]: 3
#
# c3.sno
# Out[53]: 4

# %%
class Atm:
    __counter = 1
    
    def __init__(self):
        self.__pin = ""
        self.__balance =0
        self.sno = Atm.__counter
        Atm.__counter += 1
    @staticmethod
    def get_counter():
        return Atm.__counter
    @staticmethod
    def set_counter(new):
        if type(new)==int:
            Atm.__counter = new
            
        else:
            print("Not ALlowed")

# %% [markdown]
# # Relationship between Classes --> Aggregation and Inheritance

# %% [markdown]
# Aggregation --> Has A
# Inheritance --> Is A

# %% [markdown]
# ## Aggregation
#
# Suppose there are two classes , Customer and Address
#
# and Customer has a Address
#
#  This relationship is called aggregation
#
#  ![image.png](attachment:image.png)

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address
        
        
class Address:
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode=pincode
        self.state=state
        
add = Address("Lalitpur",44200,"Bagmati")
cust = Customer("Bimal","male",add)

print(cust.address.pincode)
# Out:
# 44200

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Sep 12 18:07:49 2025

@author: BIMAL
"""

class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address
        
        
    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.change_address(new_city,new_pin,new_state)
        
        
class Address:
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode=pincode
        self.state=state
        
    def change_address(self,new_city,new_pincode,new_state):
        self.city = new_city
        self.pincode = new_pincode
        self.state = new_state
        
add = Address("Lalitpur",44200,"Bagmati")
cust = Customer("Bimal","male",add)

cust.edit_profile("Rachana","Kathmandu",44000,"Karnali")


print(cust.name)
# Out:
# Rachana

# %% [markdown]
# # Inheritance -- >>> Code Reusability
# 2082/05/27  06:24 PM
#
# DRY --> Don't Repeat Yourself
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When a child class inherites a parent class , folllowing are inheritated
#
# 1. Data Members (Variables)
# 2. Methods
# 3. Constructor
#
# But , private members(__) are not inheritated

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Sep 12 18:26:40 2025

@author: BIMAL
"""

class User:
    
    def login(self):
        print("Login")
        
    def register(self):
        print("register")
        
class Student(User):
    
    def enroll(self):
        print("Enroll")
        
    def review(self):
        print("Review")
        
        
        
s1 = Student()

s1.enroll()
s1.review()
s1.login()
s1.register()
# Out:
# Enroll
# Review
# Login
# register

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Method Overriding--> Polymorphism

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone constructor")
        self.price = price 
        self.__brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a phone")



class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a smartphone from SmartPhone class")

s= SmartPhone(20000,"Samsung","64MP")
s.buy()
# Child class can not access the private members of the parent class
# print(s.__brand)
# Out:
# Inside Phone constructor
# Buying a smartphone from SmartPhone class

# %% [markdown]
# ABove's example shows that if you create a object of a class B that inheritates class A , and given that class B did not have any constructor ,, then the constructor of class A will run .

# %%
class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num
    
class Child(Parent):
    def show(self):
        print("This is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %% [markdown]
# # Example 2
# bjdjshjasd js

# %%
class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num
    
class Child(Parent):
    def __init__(self,val,num):
        self.__val = val

    def show(self):
        print("This is in child class")

son = Child(100,10)
# print(son.get_num())
son.show()
# Out:
# This is in child class

# %% [markdown]
# 2082/06/05  08:44 PM
# # OOP Continued( with quick revision)

# %%
class User:
    
    def login(self):
        print("Login")
        
    def register(self):
        print("Register")
        
        
class Student(User):
    
    def enroll(self):
        print("Enroll")
        
    def review(self):
        print("Review")
        
s1 = Student()

s1.enroll()
s1.review()
s1.login()
s1.register()
# Out:
# Enroll
# Review
# Login
# Register

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 21 20:47:14 2025

@author: BIMAL
"""

class Phone:
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
        
class SmartPhone(Phone):
    pass

s = SmartPhone(40000, "Samsung", "64 MP")
print(s.brand)
# Out:
# Inside phone constructor
# Samsung

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 21 20:47:14 2025

@author: BIMAL
"""

class Phone:
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a Phone")
        
class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smartphone")

s = SmartPhone(40000, "Samsung", "64 MP")
s.buy()

# Method Overriding --> Polymorphism
# Method Overloading
# Operatoe Overloading
# Out:
# Inside phone constructor
# Buying a Smartphone

# %% [markdown]
# # 2082/06/29  10:39 AM, @Home, Bidhyapur
# # After Dashin

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 21 20:56:30 2025

@author: BIMAL
"""

# 2082/06/29  10:41 AM, @ Home, Bidhyapur

class Parent:
    def __init__(self, num):
        self.__num = num
        
    def get_num(self):
        return self.__num
    
class Child(Parent):
    def show(self):
        print("This is in child class")
        
son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 21 20:56:30 2025

@author: BIMAL
"""

# 2082/06/29  10:41 AM, @ Home, Bidhyapur

class Parent:
    def __init__(self, num):
        self.__num = num
        
    def get_num(self):
        return self.__num
    
class Child(Parent):
    def __init__(self,val,num):
        self.__val=val
    def get_val(self):
        return self.__val
        
son = Child(100,200)
# print("Parent Num",son.get_num())
print("Child val",son.get_val())
# Out:
# Child val 100

# %%
class A:
    def __init__(self):
        self.var1 = 100
        
    def display1(self,var1):
        print("Class A :", self.var1)
        
class B(A):
    
    def display2(self, var1):
        print("Class B :",self.var1)
        
obj = B()
obj.display1(100)
# Out:
# Class A : 100

# %% [markdown]
# # Using Super()

# %%
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone constructor")
        self.__price = price 
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a Phone")
        
class SmartPhone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        super().__init__(price,brand,camera)
        self.os = os
        self.ram = ram
        
s = SmartPhone(20000,"Samsung","48 MP","Android",8)

print(s.os)
print(s.brand)
# Out:
# Inside Phone constructor
# Android
# Samsung

# %% [markdown]
# 2082/06/29  01:06 PM

# %%
# -*- coding: utf-8 -*-
# """
# Created on Wed Oct 15 11:24:22 2025

# @author: BIMAL
# """

# class Parent:
    
#     def __init__(self,num):
#         self.__num =num
        
#     def get_num(self):
#         return self.__num
        
# class Child(Parent):
    
#     def __init__(self,num,val):
#         super().__init__(num)
#         self.__val = val
        
#     def get_val(self):
#         return self.__val
    
# son = Child(100,200)
# print(son.get_num())
# print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num = 100
        
class Child(Parent):
    def __init__(self):
        super().__init__()
        self.var = 200
        
    def show(self):
        print(self.num)
        print(self.var)
        
son = Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num = 100
        
    def show(self):
        print("Parent :",self.__num)
        
class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var = 20
        
    def show(self):
        print("Child ;",self.__var)
        
dad = Parent()
dad.show()
son = Child()
son.show()
# Out:
# Parent : 100
# Child ; 20

# %% [markdown]
# ## Types if Inheritance in Python
# - Single Level Inheritance ( One Chils, One Parent)
# - Multi-Level,one inheritates from other in sequence (GrandFather->Father->Son--->>>.)
# - Hierarchical ( One Parent and Multiple Children)
# - Multiple Inheritance ( One Child , Two Parents)
# - Hybrid Inheritance ( Combination of aboves type)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Methos Resolution Order (MRO)
# ## The Order of inheritance will decide the priority

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Oct 15 16:11:45 2025

@author: BIMAL
"""

class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a Phone")
        
class Product:
    def buy(self):
        print("Product buy method")
        
class SmartPhone(Product,Phone): # Here Product class will get the priority
    pass

s = SmartPhone(15000, "Samsung", 12)

s.buy()
# Out:
# Inside Phone Constructor
# Product buy method

# %% [markdown]
# # Polymorphism
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
class Geometry:

    def area(self,radius):
        return 3.14*radius*radius
    def area(self,l,b):
        return l*B
    
obj = Geometry()
print(obj.area(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 9
#       6         return l*B
#       8 obj = Geometry()
# ----> 9 print(obj.area(5))
#
# TypeError: Geometry.area() missing 1 required positional argument: 'b'

# %% [markdown]
# # Method Overloading
# to fix above problem, we can change the logic

# %%
class Geometry:

    def area(self,a,b=0):
        if b==0:
            print("Circle",3.14*a*a)
            
        else:
            print("Rectangle",a*b)
    
obj = Geometry()
obj.area(2)
obj.area(2,3)
# Out:
# Circle 12.56
# Rectangle 6

# %% [markdown]
# # Operator Overloading
